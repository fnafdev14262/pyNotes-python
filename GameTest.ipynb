# %%
print("The 30 Minute Python Game")
# Out:
# The 30 Minute Python Game

# %%
input("Press Enter to continue...")
# Out:
# Press Enter to continue...
# ''

# %%
name = input("What is your NAME?")
soul_color = input("Choose a number:")

if soul_color == '1':
    print("Your SOUL is Determination")
elif soul_color == '2':
    print("Your SOUL is Patience")
elif soul_color == '3':
    print("Your SOUL is Bravery")
elif soul_color == '4':
    print("Your SOUL is Integrity")
elif soul_color == '5':
    print("Your SOUL is Perseverance")
elif soul_color == '6':
    print("Your SOUL is Kindness")
elif soul_color == '7':
    print("Your SOUL is Justice")
else:
    print("Invalid choice")
# Out:
# What is your NAME?
# Choose a number:
# Invalid choice

# %%
input("Press Enter to continue...")
# Out:
# Press Enter to continue...
# ''

# %%
print("You finally woke up")
input("Press Enter to continue...")
# Out:
# You finally woke up
# Press Enter to continue...
# ''

# %%
print("Do you want a BEER")
input("Press Enter to continue...")
# Out:
# Do you want a BEER
# Press Enter to continue...
# ''

# %%
print("The Game Has Ended NOW(FOR NOW)")
exit()
# Out:
# The Game Has Ended NOW(for now)
