# %%
print("The Python Game")
# Out:
# The Python Game

# %%
name = input("What is your name?")
age = int(input("How old are you?"))
photosensitive = input("Are you photosensitive? (yes/no): ").lower()=="yes"
member = input("Are you a member? (yes/no): ").lower()=="yes"
group = input("Are you in a group? (yes/no): ").lower()=="yes"
# Out:
# What is your name? Haruki
# How old are you? 8
# Are you photosensitive? (yes/no):  yes
# Are you a member? (yes/no):  no
# Are you in a group? (yes/no):  no

# %%
print("You are", name, "You are", age, "years old")
# Out:
# You are Haruki You are 8 years old

# %%
if age >=21 and member:
   print(name, "is allowed in as VIP")
if age >=21 and member and group:
    print(name, "is allowed in as Group VIP")
elif age >=21 and not member or group:
    print(name, "is allowed in")
elif age <=21 and not member:
     print(name, "is not allowed in at all")
elif age <=21 and member:
    print(name, "is allowed in with restricted access")
# Out:
# Haruki is not allowed in at all
