# %%
### Print a welcome message
print("This is CYAG")
input("Press ENTER to continue")
print("What is your name traveler?")
name = input("Write your name")
# Out:
# This is CYAG
# Press ENTER to continue
# What is your name traveler?
# Write your name

# %%
print("Hello,", name + ".", " You finally woke up from your injuries")
input("Press ENTER to continue")
print("Hey", name, "here's a Health Potion to heal your injuries")
print("You have a Health Potion")
print("1. Drink it.")
print("2. Save it.")
# Get the player's choice as input
choice = input("Enter your choice (1. or 2.) ")
# Use conditional statements to act on the choice
if choice == "1.":
    print("You drank it. You healed 10 HP")
    # Add the code for the forest path here
elif choice == "2.":
    print("You didn't drink it.")
    # Add the code for the cave path here
else:
    # Handle any other input
    print("Invalid choice. Please enter '1.' or '2.'.")

print("What path will you choose ")
print("1. The Action Path.")
print("2. The Fame Path .")
print("3. The Coding Path.")
# Get the player's choice as input
choice1 = input("Enter your choice (1 or 2 or 3): ")

# Use conitional statements to act on the choice
if choice1 == "1":
    print("You need to find the best knight in the world.")
elif choice1 == "2":
    print("You need to find the most famous person in the world.")
    # Add the code for the cave path here
elif choice1 == "3":
    print("You need to find the best programmer in the world.")
    # Add the code for the cave path here
else:
    # Handle any other input
    print("Invalid choice. Please enter '1' or '2' or '3'.")
# Out:
# Hello, .  You finally woke up from your injuries
# Press ENTER to continue
# Hey  here's a Health Potion to heal your injuries
# You have a Health Potion
# 1. Drink it.
# 2. Save it.
# Enter your choice (1. or 2.)
# Invalid choice. Please enter '1.' or '2.'.
# What path will you choose
# 1. The Action Path.
# 2. The Fame Path .
# 3. The Coding Path.
# Enter your choice (1 or 2 or 3):
# Invalid choice. Please enter '1' or '2' or '3'.

# %%
print("You get dropped off at the 'Crossroads'")
print("You stand at a crossroads.")
print("1. Go left to the forest.")
print("2. Go right to the cave.")

# Get the player's choice as input
choice2 = input("Enter your choice (1 or 2): ")

# Use conditional statements to act on the choice
if choice2 == "1":
    print("You chose to go left. You enter the dark forest.")
    # Add the code for the forest path here
elif choice2 == "2":
    print("You chose to go right. You enter the damp cave.")
    # Add the code for the cave path here
else:
    # Handle any other input
    print("Invalid choice. Please enter '1' or '2'.")

# %%
print("Cave Theory")
# Out:
# Cave Theory

# %%
print("The Cave Theory Is DONE")
# Out:
# The Cave Theory Is DONE
